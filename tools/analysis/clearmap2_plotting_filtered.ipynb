# %%
import tifffile as tif

import matplotlib.pyplot as plt, numpy as np, cv2, os, pandas as pd

import matplotlib.colors

from matplotlib.backends.backend_pdf import PdfPages

# %%
z265 = np.load("/home/emilyjanedennis/Desktop/brains/z265/z265_cells_filtered.npy")
z266 = np.load("/home/emilyjanedennis/Desktop/brains/z266/z266_debug_cells_filtered.npy")
z267 = np.load("/home/emilyjanedennis/Desktop/brains/z267/debug_cells_filtered.npy")
z268_0 = np.load("/home/emilyjanedennis/Desktop/brains/z268/_ch00_cells_filtered.npy")
z268_1 = np.load("/home/emilyjanedennis/Desktop/brains/z268/_ch01_cells_filtered.npy")
z269_1 = np.load("/home/emilyjanedennis/Desktop/brains/z269/_ch01_cells_filtered.npy")

# %%
z6df = pd.DataFrame(z266)
z7df = pd.DataFrame(z267)
z8_0df = pd.DataFrame(z268_0)
z8_1df = pd.DataFrame(z268_1)
z9df = pd.DataFrame(z269_1)

# %%
z5df = pd.DataFrame(z265)

# %%
plt.scatter(z8_1df["x"],z8_1df["y"],alpha=0.05,s=2,color="k")

# %%
plt.scatter(z6df["x"],z6df["y"],alpha=0.1,s=1,color="k")

# %%
plt.scatter(z8_0df["x"],z8_0df["y"],alpha=0.1,s=1,color="k")

# %%
plt.scatter(z5df["x"],z5df["y"],alpha=0.2,s=1,color="k")

# %%
plt.scatter(z7df["x"],z7df["y"],alpha=0.1,s=1,color="k")

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
z=np.load('/home/emilyjanedennis/Desktop/intensities-allpoints.npy')

# %%
z269 =
# Out:
# array([[1.567e+03, 2.760e+02, 2.760e+02, 1.000e+00],
#        [1.457e+03, 2.220e+02, 2.220e+02, 1.000e+00],
#        [1.911e+03, 3.220e+02, 3.220e+02, 1.000e+00],
#        ...,
#        [1.965e+03, 2.950e+02, 2.950e+02, 1.000e+00],
#        [2.134e+03, 2.880e+02, 2.880e+02, 1.000e+00],
#        [1.527e+03, 2.260e+02, 2.260e+02, 1.000e+00]])

# %%
zipd = pd.DataFrame(data=z,columns=["a","b","c","d"])

# %%
zpd= pd.DataFrame(data=z269,columns=["x","y","z"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-08d48193ef95> in <module>
# ----> 1 zpd= pd.DataFrame(data=z269,columns=["x","y","z"])
#       2 zpdtest=zpd["z" ==400]
#
# NameError: name 'z269' is not defined

# %%
zpdtest=zpd[zpd["z"] ==300]
zipd4=zipd[zpd["x"]==300]

# %%
plt.scatter(zpdtest["x"],zpdtest["y"],s=.00001)

# %%
z2=np.load('/home/emilyjanedennis/scratch/clearmap_out/z269/clearmap_cluster_output/cells-allpoints.npy')

# %%
zpd = pd.DataFrame(data=z2,columns=["x","y","z"])

# %%
zpd
# Out:
#               x     y    z
# 0          2158  4555   13
# 1          2159  4556   13
# 2          2165  4367   13
# 3          2174  4375   13
# 4          2188  4424   13
# ...         ...   ...  ...
# 251464403  7142  4900  449
# 251464404  7143  5044  449
# 251464405  7144  5043  449
# 251464406  7144  5047  449
# 251464407  7145  5048  450
#
# [251464408 rows x 3 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tifffile as tif

# %%
z=np.load('/home/emilyjanedennis/Desktop/brains/z265/debug_cells_raw.npy')

# %%
z
# Out:
# array([(4513, 7315,   1, 1,  1540074.), ( 796, 4121,   2, 1,  1931059.),
#        ( 762, 4102,   3, 9,  2584956.), ...,
#        (6584, 3647, 605, 2, 27602917.), (6584, 3671, 605, 4, 27602918.),
#        (6606, 3800, 605, 3, 27605794.)],
#       dtype=[('x', '<i8'), ('y', '<i8'), ('z', '<i8'), ('size', '<i8'), ('source', '<f8')])

# %%
zipd = pd.DataFrame(data=z,columns=["x","y","z","size","source"])

# %%
zz = zipd[zipd["z"]>310]
zz = zz[zz["z"]<330]
plt.scatter(zz["x"],zz["y"],s=5,alpha=0.2)
plt.xlim([0,7300])
plt.ylim([0,8700])
# Out:
# (0.0, 8700.0)

# %%
plt.hist(zipd["z"],bins=600)
plt.show()

# %%
plt.scatter(zpdtest["x"],zpdtest["y"],s=.00001)

# %%
z2=np.load('/home/emilyjanedennis/scratch/clearmap_out/z269/clearmap_cluster_output/cells-allpoints.npy')

# %%
zpd = pd.DataFrame(data=z2,columns=["x","y","z"])

# %%
zpd
# Out:
#               x     y    z
# 0          2158  4555   13
# 1          2159  4556   13
# 2          2165  4367   13
# 3          2174  4375   13
# 4          2188  4424   13
# ...         ...   ...  ...
# 251464403  7142  4900  449
# 251464404  7143  5044  449
# 251464405  7144  5043  449
# 251464406  7144  5047  449
# 251464407  7145  5048  450
#
# [251464408 rows x 3 columns]
